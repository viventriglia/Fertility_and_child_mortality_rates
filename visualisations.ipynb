# %%
import matplotlib.pyplot as pp
import pandas as pd
import numpy as np

from IPython import display
from ipywidgets import interact, widgets
from ipywidgets.embed import embed_minimal_html

# %matplotlib inline

# %%
gapminder = pd.read_csv('gapminder.csv')

# %%
def plotyear(year):
    data = gapminder[gapminder.year == year]
    area = 5e-6 * data.population
    colours = data.region.map({'Africa':'skyblue','Europe':'gold','America':'palegreen', 'Asia':'coral'})
    
    data.plot.scatter('babies_per_woman', 'age5_surviving',
                     s=area, c=colours, linewidths=1, edgecolors='k', figsize=(12,9))
    
    pp.axis(xmin=0, xmax=8, ymin=50, ymax=105)
    pp.xlabel('babies per woman')
    pp.ylabel('% of children alive at the age of 5')
    pp.title(f'{year}')

# %%
interact(plotyear, year=widgets.IntSlider(min=1950, max=2015, step=1, value=1970))
# Out:
# interactive(children=(IntSlider(value=1970, description='year', max=2015, min=1950), Output()), _dom_classes=(…
# <function __main__.plotyear(year)>

# %%
for year in range(1950,2016,1):
    plotyear(year)
    pp.savefig(f'images/{year}.png', bbox_inches="tight", dpi=72)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
